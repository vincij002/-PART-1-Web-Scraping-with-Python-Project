# %%
import pandas as pd

# %%
matches = pd.read_csv("matches.csv", index_col=0)

# %%
matches.head()
# Out:
#          date   time     comp        round  day venue result   gf   ga  \
# 1  2024-08-19  18:30  Serie A  Matchweek 1  Mon  Away      W  4.0  0.0
# 2  2024-08-25  18:30  Serie A  Matchweek 2  Sun  Away      L  1.0  2.0
# 3  2024-08-30  20:45  Serie A  Matchweek 3  Fri  Away      L  0.0  4.0
# 4  2024-09-15  15:00  Serie A  Matchweek 4  Sun  Home      W  3.0  2.0
# 6  2024-09-24  20:45  Serie A  Matchweek 5  Tue  Home      L  2.0  3.0
#
#      opponent  ...  match report  notes    sh  sot  dist   fk pk pkatt season  \
# 1       Lecce  ...  Match Report    NaN  10.0  5.0  13.4  0.0  1     1   2025
# 2      Torino  ...  Match Report    NaN  24.0  8.0  16.0  1.0  0     1   2025
# 3       Inter  ...  Match Report    NaN  11.0  1.0  17.1  0.0  0     0   2025
# 4  Fiorentina  ...  Match Report    NaN  13.0  7.0  13.6  0.0  0     0   2025
# 6        Como  ...  Match Report    NaN   7.0  4.0  20.0  0.0  1     1   2025
#
#        team
# 1  Atalanta
# 2  Atalanta
# 3  Atalanta
# 4  Atalanta
# 6  Atalanta
#
# [5 rows x 28 columns]

# %%
matches.shape
# Out:
# (1096, 28)

# %%
matches["team"].value_counts()
# Out:
# team
# Atalanta          55
# Roma              55
# Monza             55
# Cagliari          55
# Hellas Verona     55
# Lecce             55
# Genoa             55
# Napoli            55
# Empoli            55
# Torino            55
# Udinese           55
# Juventus          55
# Lazio             55
# Milan             54
# Bologna           54
# Fiorentina        54
# Internazionale    54
# Frosinone         38
# Sassuolo          38
# Salernitana       38
# Parma             17
# Como              17
# Venezia           17
# Name: count, dtype: int64

# %%
matches["round"].value_counts()
# Out:
# round
# Matchweek 1     40
# Matchweek 16    40
# Matchweek 3     40
# Matchweek 4     40
# Matchweek 5     40
# Matchweek 6     40
# Matchweek 7     40
# Matchweek 8     40
# Matchweek 2     40
# Matchweek 10    40
# Matchweek 11    40
# Matchweek 12    40
# Matchweek 13    40
# Matchweek 17    40
# Matchweek 15    40
# Matchweek 14    38
# Matchweek 9     38
# Matchweek 28    20
# Matchweek 37    20
# Matchweek 36    20
# Matchweek 35    20
# Matchweek 34    20
# Matchweek 33    20
# Matchweek 32    20
# Matchweek 31    20
# Matchweek 30    20
# Matchweek 29    20
# Matchweek 20    20
# Matchweek 27    20
# Matchweek 21    20
# Matchweek 26    20
# Matchweek 25    20
# Matchweek 24    20
# Matchweek 23    20
# Matchweek 22    20
# Matchweek 19    20
# Matchweek 18    20
# Matchweek 38    20
# Name: count, dtype: int64

# %%
matches.dtypes
# Out:
# date              object
# time              object
# comp              object
# round             object
# day               object
# venue             object
# result            object
# gf               float64
# ga               float64
# opponent          object
# xg               float64
# xga              float64
# poss             float64
# attendance       float64
# captain           object
# formation         object
# opp formation     object
# referee           object
# match report      object
# notes            float64
# sh               float64
# sot              float64
# dist             float64
# fk               float64
# pk                 int64
# pkatt              int64
# season             int64
# team              object
# dtype: object

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches["target"] = (matches["result"] == "W").astype("int")

# %%
matches
# Out:
#          date   time     comp         round  day venue result   gf   ga  \
# 1  2024-08-19  18:30  Serie A   Matchweek 1  Mon  Away      W  4.0  0.0
# 2  2024-08-25  18:30  Serie A   Matchweek 2  Sun  Away      L  1.0  2.0
# 3  2024-08-30  20:45  Serie A   Matchweek 3  Fri  Away      L  0.0  4.0
# 4  2024-09-15  15:00  Serie A   Matchweek 4  Sun  Home      W  3.0  2.0
# 6  2024-09-24  20:45  Serie A   Matchweek 5  Tue  Home      L  2.0  3.0
# ..        ...    ...      ...           ...  ...   ...    ...  ...  ...
# 36 2024-04-26  20:45  Serie A  Matchweek 34  Fri  Away      L  0.0  3.0
# 37 2024-05-06  18:00  Serie A  Matchweek 35  Mon  Home      L  1.0  2.0
# 38 2024-05-12  18:00  Serie A  Matchweek 36  Sun  Away      D  1.0  1.0
# 39 2024-05-20  18:30  Serie A  Matchweek 37  Mon  Home      L  1.0  2.0
# 40 2024-05-25  20:45  Serie A  Matchweek 38  Sat  Away      D  3.0  3.0
#
#          opponent  ...  notes    sh  sot  dist   fk pk pkatt season  \
# 1           Lecce  ...    NaN  10.0  5.0  13.4  0.0  1     1   2025
# 2          Torino  ...    NaN  24.0  8.0  16.0  1.0  0     1   2025
# 3           Inter  ...    NaN  11.0  1.0  17.1  0.0  0     0   2025
# 4      Fiorentina  ...    NaN  13.0  7.0  13.6  0.0  0     0   2025
# 6            Como  ...    NaN   7.0  4.0  20.0  0.0  1     1   2025
# ..            ...  ...    ...   ...  ...   ...  ... ..   ...    ...
# 36      Frosinone  ...    NaN  17.0  2.0  21.4  1.0  0     0   2024
# 37       Atalanta  ...    NaN   9.0  2.0  21.2  1.0  0     0   2024
# 38       Juventus  ...    NaN  13.0  4.0  20.4  1.0  0     0   2024
# 39  Hellas Verona  ...    NaN   9.0  1.0  19.9  0.0  0     0   2024
# 40          Milan  ...    NaN  14.0  6.0  18.5  1.0  0     0   2024
#
#            team  target
# 1      Atalanta       1
# 2      Atalanta       0
# 3      Atalanta       0
# 4      Atalanta       1
# 6      Atalanta       0
# ..          ...     ...
# 36  Salernitana       0
# 37  Salernitana       0
# 38  Salernitana       0
# 39  Salernitana       0
# 40  Salernitana       0
#
# [1096 rows x 29 columns]

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches
# Out:
#          date   time     comp         round  day venue result   gf   ga  \
# 1  2024-08-19  18:30  Serie A   Matchweek 1  Mon  Away      W  4.0  0.0
# 2  2024-08-25  18:30  Serie A   Matchweek 2  Sun  Away      L  1.0  2.0
# 3  2024-08-30  20:45  Serie A   Matchweek 3  Fri  Away      L  0.0  4.0
# 4  2024-09-15  15:00  Serie A   Matchweek 4  Sun  Home      W  3.0  2.0
# 6  2024-09-24  20:45  Serie A   Matchweek 5  Tue  Home      L  2.0  3.0
# ..        ...    ...      ...           ...  ...   ...    ...  ...  ...
# 36 2024-04-26  20:45  Serie A  Matchweek 34  Fri  Away      L  0.0  3.0
# 37 2024-05-06  18:00  Serie A  Matchweek 35  Mon  Home      L  1.0  2.0
# 38 2024-05-12  18:00  Serie A  Matchweek 36  Sun  Away      D  1.0  1.0
# 39 2024-05-20  18:30  Serie A  Matchweek 37  Mon  Home      L  1.0  2.0
# 40 2024-05-25  20:45  Serie A  Matchweek 38  Sat  Away      D  3.0  3.0
#
#          opponent  ...   fk  pk  pkatt  season         team target venue_code  \
# 1           Lecce  ...  0.0   1      1    2025     Atalanta      1          0
# 2          Torino  ...  1.0   0      1    2025     Atalanta      0          0
# 3           Inter  ...  0.0   0      0    2025     Atalanta      0          0
# 4      Fiorentina  ...  0.0   0      0    2025     Atalanta      1          1
# 6            Como  ...  0.0   1      1    2025     Atalanta      0          1
# ..            ...  ...  ...  ..    ...     ...          ...    ...        ...
# 36      Frosinone  ...  1.0   0      0    2024  Salernitana      0          0
# 37       Atalanta  ...  1.0   0      0    2024  Salernitana      0          1
# 38       Juventus  ...  1.0   0      0    2024  Salernitana      0          0
# 39  Hellas Verona  ...  0.0   0      0    2024  Salernitana      0          1
# 40          Milan  ...  1.0   0      0    2024  Salernitana      0          0
#
#    opp_code hour  day_code
# 1        12   18         0
# 2        20   18         6
# 3         9   20         4
# 4         5   15         6
# 6         3   20         1
# ..      ...  ...       ...
# 36        6   20         4
# 37        0   18         0
# 38       10   18         6
# 39        8   18         0
# 40       13   20         5
#
# [1096 rows x 33 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["date"] < '2024-01-01']

# %%
test = matches[matches["date"] > '2024-01-01']

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds)

# %%
acc
# Out:
# 0.6059782608695652

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted    0   1
# actual
# 0          382  94
# 1          196  64

# %%
from sklearn.metrics import precision_score

precision_score(test["target"], preds)
# Out:
# 0.4050632911392405

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Atalanta").sort_values("date")

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

rolling_averages(group, cols, new_cols)
# Out:
#          date   time     comp         round  day venue result   gf   ga  \
# 3  2023-09-17  18:00  Serie A   Matchweek 4  Sun  Away      L  2.0  3.0
# 5  2023-09-24  15:00  Serie A   Matchweek 5  Sun  Home      W  2.0  0.0
# 6  2023-09-27  18:30  Serie A   Matchweek 6  Wed  Away      W  1.0  0.0
# 7  2023-10-01  18:00  Serie A   Matchweek 7  Sun  Home      D  0.0  0.0
# 9  2023-10-08  15:00  Serie A   Matchweek 8  Sun  Away      L  2.0  3.0
# 10 2023-10-22  18:00  Serie A   Matchweek 9  Sun  Home      W  2.0  0.0
# 12 2023-10-30  18:30  Serie A  Matchweek 10  Mon  Away      W  3.0  0.0
# 13 2023-11-04  18:00  Serie A  Matchweek 11  Sat  Home      L  1.0  2.0
# 15 2023-11-12  15:00  Serie A  Matchweek 12  Sun  Away      D  1.0  1.0
# 12 2024-10-26  20:45  Serie A   Matchweek 9  Sat  Home      W  6.0  1.0
# 13 2024-10-30  20:45  Serie A  Matchweek 10  Wed  Home      W  2.0  0.0
# 14 2024-11-03  12:30  Serie A  Matchweek 11  Sun  Away      W  3.0  0.0
# 16 2024-11-10  12:30  Serie A  Matchweek 12  Sun  Home      W  2.0  1.0
# 17 2024-11-23  20:45  Serie A  Matchweek 13  Sat  Away      W  3.0  1.0
# 19 2024-12-02  20:45  Serie A  Matchweek 14  Mon  Away      W  2.0  0.0
# 20 2024-12-06  20:45  Serie A  Matchweek 15  Fri  Home      W  2.0  1.0
# 22 2024-12-14  15:00  Serie A  Matchweek 16  Sat  Away      W  1.0  0.0
# 24 2024-12-22  18:00  Serie A  Matchweek 17  Sun  Home      W  3.0  2.0
#
#          opponent  ...  hour  day_code  gf_rolling  ga_rolling sh_rolling  \
# 3      Fiorentina  ...    18         6    2.000000    0.666667  17.333333
# 5        Cagliari  ...    15         6    2.000000    1.666667  15.666667
# 6   Hellas Verona  ...    18         2    2.333333    1.000000  13.000000
# 7        Juventus  ...    18         6    1.666667    1.000000   9.666667
# 9           Lazio  ...    15         6    1.000000    0.000000  11.000000
# 10          Genoa  ...    18         6    1.000000    1.000000  11.666667
# 12         Empoli  ...    18         0    1.333333    1.000000  13.333333
# 13          Inter  ...    18         5    2.333333    1.000000  14.333333
# 15        Udinese  ...    15         6    2.000000    0.666667  15.000000
# 16         Napoli  ...    18         5    1.666667    1.000000  13.333333
# 18         Torino  ...    20         0    1.000000    1.666667  12.666667
# 19          Milan  ...    18         5    0.666667    2.000000  11.333333
# 21    Salernitana  ...    20         0    1.333333    2.333333  15.000000
# 22        Bologna  ...    15         5    2.333333    2.000000  16.333333
# 23          Lecce  ...    12         5    2.333333    1.333333  17.000000
# 25           Roma  ...    20         6    1.666667    0.666667  16.333333
# 27      Frosinone  ...    20         0    0.666667    0.666667  12.333333
# 28        Udinese  ...    15         5    2.333333    0.333333  15.000000
# 29          Lazio  ...    18         6    2.666667    0.333333  14.000000
# 30          Genoa  ...    18         6    3.333333    0.333333  17.333333
# 31       Sassuolo  ...    20         5    3.000000    0.666667  15.333333
# 32          Milan  ...    20         6    3.333333    0.666667  19.666667
# 33          Inter  ...    20         2    2.666667    0.666667  16.000000
# 34        Bologna  ...    18         6    1.333333    1.666667  13.333333
# 36       Juventus  ...    18         6    0.666667    2.333333   8.000000
# 38         Napoli  ...    12         5    1.000000    2.666667   8.000000
# 40       Cagliari  ...    18         6    2.000000    1.333333  10.000000
# 42  Hellas Verona  ...    20         0    2.000000    1.333333   8.666667
# 44          Monza  ...    20         6    2.000000    1.333333  11.666667
# 46         Empoli  ...    18         6    1.666667    1.666667  11.666667
# 48    Salernitana  ...    18         0    2.000000    1.000000  14.666667
# 50           Roma  ...    20         6    2.000000    0.666667  15.000000
# 52          Lecce  ...    18         5    2.000000    0.666667  19.000000
# 54         Torino  ...    18         6    2.000000    0.666667  20.000000
# 55     Fiorentina  ...    18         6    2.333333    0.333333  20.000000
# 55    7.333333    16.533333   0.333333   0.333333       0.333333
# 1     6.000000    15.666667   0.000000   0.333333       0.333333
# 2     4.666667    14.700000   0.000000   0.666667       0.666667
# 3     5.333333    14.933333   0.333333   0.333333       0.666667
# 4     4.666667    15.500000   0.333333   0.333333       0.666667
# 6     5.333333    15.566667   0.333333   0.000000       0.333333
# 7     4.000000    16.900000   0.000000   0.333333       0.333333
# 9     5.000000    16.600000   0.000000   0.333333       0.333333
# 10    5.000000    17.166667   0.000000   0.666667       0.666667
# 12    6.000000    15.733333   0.000000   0.333333       0.333333
# 13    8.000000    15.433333   0.000000   0.333333       0.333333
# 14    7.333333    16.700000   0.666667   0.000000       0.000000
# 16    6.000000    16.033333   0.666667   0.000000       0.000000
# 17    3.666667    15.066667   0.666667   0.000000       0.000000
# 19    4.000000    13.033333   0.000000   0.000000       0.000000
# 20    5.333333    13.500000   0.333333   0.000000       0.000000
# 22    7.000000    14.066667   0.333333   0.000000       0.000000
# 24    5.666667    14.366667   0.333333   0.000000       0.000000
#
# [52 rows x 41 columns]

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
# Out:
# C:\Users\jonat\AppData\Local\Temp\ipykernel_6292\4052147919.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                   date   time     comp         round  day venue result   gf  \
# team
# Atalanta 3  2023-09-17  18:00  Serie A   Matchweek 4  Sun  Away      L  2.0
#          5  2023-09-24  15:00  Serie A   Matchweek 5  Sun  Home      W  2.0
#          6  2023-09-27  18:30  Serie A   Matchweek 6  Wed  Away      W  1.0
#          7  2023-10-01  18:00  Serie A   Matchweek 7  Sun  Home      D  0.0
#          9  2023-10-08  15:00  Serie A   Matchweek 8  Sun  Away      L  2.0
# ...                ...    ...      ...           ...  ...   ...    ...  ...
# Venezia  13 2024-11-25  20:45  Serie A  Matchweek 13  Mon  Home      L  0.0
#          14 2024-11-30  20:45  Serie A  Matchweek 14  Sat  Away      L  0.0
#          15 2024-12-08  18:00  Serie A  Matchweek 15  Sun  Home      D  2.0
#          16 2024-12-14  20:45  Serie A  Matchweek 16  Sat  Away      D  2.0
#          17 2024-12-22  15:00  Serie A  Matchweek 17  Sun  Home      W  2.0
#
#               ga       opponent  ...  hour  day_code  gf_rolling  ga_rolling  \
# team                             ...
# Atalanta 3   3.0     Fiorentina  ...    18         6    2.000000    0.666667
#          5   0.0       Cagliari  ...    15         6    2.000000    1.666667
#          6   0.0  Hellas Verona  ...    18         2    2.333333    1.000000
#          7   0.0       Juventus  ...    18         6    1.666667    1.000000
#          9   3.0          Lazio  ...    15         6    1.000000    0.000000
# ...          ...            ...  ...   ...       ...         ...         ...
# Venezia  13  1.0          Lecce  ...    20         0    1.333333    1.666667
#          14  3.0        Bologna  ...    20         5    0.333333    1.333333
#          15  2.0           Como  ...    18         6    0.333333    2.000000
#          16  2.0       Juventus  ...    20         5    0.666667    2.000000
#          17  1.0       Cagliari  ...    15         6    1.333333    2.333333
#
#             sh_rolling sot_rolling dist_rolling fk_rolling pk_rolling  \
# team
# Atalanta 3   17.333333    6.000000    16.533333   0.000000   0.000000
#          5   15.666667    6.000000    16.266667   0.000000   0.000000
#          6   13.000000    6.000000    15.866667   0.000000   0.000000
#          7    9.666667    4.000000    15.833333   0.000000   0.000000
#          9   11.000000    3.333333    16.033333   0.333333   0.000000
# ...                ...         ...          ...        ...        ...
# Venezia  13  11.666667    4.333333    19.866667   0.666667   0.666667
#          14  11.666667    4.666667    16.900000   0.666667   0.000000
#          15  11.000000    4.333333    16.000000   0.666667   0.000000
#          16   9.666667    3.666667    18.866667   1.333333   0.000000
#          17   7.000000    2.333333    19.433333   1.000000   0.000000
#
#              pkatt_rolling
# team
# Atalanta 3        0.000000
#          5        0.000000
#          6        0.000000
#          7        0.000000
#          9        0.000000
# ...                    ...
# Venezia  13       0.666667
#          14       0.000000
#          15       0.000000
#          16       0.000000
#          17       0.000000
#
# [1027 rows x 41 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#          date   time     comp         round  day venue result   gf   ga  \
# 3  2023-09-17  18:00  Serie A   Matchweek 4  Sun  Away      L  2.0  3.0
# 5  2023-09-24  15:00  Serie A   Matchweek 5  Sun  Home      W  2.0  0.0
# 6  2023-09-27  18:30  Serie A   Matchweek 6  Wed  Away      W  1.0  0.0
# 7  2023-10-01  18:00  Serie A   Matchweek 7  Sun  Home      D  0.0  0.0
# 9  2023-10-08  15:00  Serie A   Matchweek 8  Sun  Away      L  2.0  3.0
# ..        ...    ...      ...           ...  ...   ...    ...  ...  ...
# 13 2024-11-25  20:45  Serie A  Matchweek 13  Mon  Home      L  0.0  1.0
# 14 2024-11-30  20:45  Serie A  Matchweek 14  Sat  Away      L  0.0  3.0
# 15 2024-12-08  18:00  Serie A  Matchweek 15  Sun  Home      D  2.0  2.0
# 16 2024-12-14  20:45  Serie A  Matchweek 16  Sat  Away      D  2.0  2.0
# 17 2024-12-22  15:00  Serie A  Matchweek 17  Sun  Home      W  2.0  1.0
#
#          opponent  ...  hour  day_code  gf_rolling  ga_rolling sh_rolling  \
# 3      Fiorentina  ...    18         6    2.000000    0.666667  17.333333
# 5        Cagliari  ...    15         6    2.000000    1.666667  15.666667
# 6   Hellas Verona  ...    18         2    2.333333    1.000000  13.000000
# 7        Juventus  ...    18         6    1.666667    1.000000   9.666667
# 9           Lazio  ...    15         6    1.000000    0.000000  11.000000
# ..            ...  ...   ...       ...         ...         ...        ...
# 13          Lecce  ...    20         0    1.333333    1.666667  11.666667
# 14        Bologna  ...    20         5    0.333333    1.333333  11.666667
# 15           Como  ...    18         6    0.333333    2.000000  11.000000
# 16       Juventus  ...    20         5    0.666667    2.000000   9.666667
# 17       Cagliari  ...    15         6    1.333333    2.333333   7.000000
#
#    sot_rolling dist_rolling fk_rolling pk_rolling  pkatt_rolling
# 3     6.000000    16.533333   0.000000   0.000000       0.000000
# 5     6.000000    16.266667   0.000000   0.000000       0.000000
# 6     6.000000    15.866667   0.000000   0.000000       0.000000
# 7     4.000000    15.833333   0.000000   0.000000       0.000000
# 9     3.333333    16.033333   0.333333   0.000000       0.000000
# ..         ...          ...        ...        ...            ...
# 13    4.333333    19.866667   0.666667   0.666667       0.666667
# 14    4.666667    16.900000   0.666667   0.000000       0.000000
# 15    4.333333    16.000000   0.666667   0.000000       0.000000
# 16    3.666667    18.866667   1.333333   0.000000       0.000000
# 17    2.333333    19.433333   1.000000   0.000000       0.000000
#
# [1027 rows x 41 columns]

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2024-01-01']
    test = data[data["date"] > '2024-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    precision = precision_score(test["target"], preds)
    return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.46153846153846156

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
combined.head(10)
# Out:
#     actual  predicted       date      team   opponent result
# 15       0          0 2024-01-07  Atalanta       Roma      D
# 16       1          0 2024-01-15  Atalanta  Frosinone      W
# 17       1          1 2024-01-27  Atalanta    Udinese      W
# 18       1          0 2024-02-04  Atalanta      Lazio      W
# 19       1          1 2024-02-11  Atalanta      Genoa      W
# 20       1          0 2024-02-17  Atalanta   Sassuolo      W
# 21       0          1 2024-02-25  Atalanta      Milan      D
# 22       0          0 2024-02-28  Atalanta      Inter      L
# 23       0          1 2024-03-03  Atalanta    Bologna      L
# 24       0          0 2024-03-10  Atalanta   Juventus      D

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"Internazionale": "Inter"}  
mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged
# Out:
#      actual_x  predicted_x       date    team_x opponent_x result_x  \
# 0           0            0 2024-01-07  Atalanta       Roma        D
# 1           1            0 2024-01-15  Atalanta  Frosinone        W
# 2           1            1 2024-01-27  Atalanta    Udinese        W
# 3           1            0 2024-02-04  Atalanta      Lazio        W
# 4           1            1 2024-02-11  Atalanta      Genoa        W
# ..        ...          ...        ...       ...        ...      ...
# 713         0            0 2024-11-25   Venezia      Lecce        L
# 714         0            0 2024-11-30   Venezia    Bologna        L
# 715         0            0 2024-12-08   Venezia       Como        D
# 716         0            0 2024-12-14   Venezia   Juventus        D
# 717         1            0 2024-12-22   Venezia   Cagliari        W
#
#     new_team_x  actual_y  predicted_y     team_y opponent_y result_y  \
# 0     Atalanta         0            0       Roma   Atalanta        D
# 1     Atalanta         0            0  Frosinone   Atalanta        L
# 2     Atalanta         0            0    Udinese   Atalanta        L
# 3     Atalanta         0            0      Lazio   Atalanta        L
# 4     Atalanta         0            1      Genoa   Atalanta        L
# ..         ...       ...          ...        ...        ...      ...
# 713    Venezia         1            0      Lecce    Venezia        W
# 714    Venezia         1            0    Bologna    Venezia        W
# 715    Venezia         0            0       Como    Venezia        D
# 716    Venezia         0            0   Juventus    Venezia        D
# 717    Venezia         0            0   Cagliari    Venezia        L
#
#     new_team_y
# 0         Roma
# 1    Frosinone
# 2      Udinese
# 3        Lazio
# 4        Genoa
# ..         ...
# 713      Lecce
# 714    Bologna
# 715       Como
# 716   Juventus
# 717   Cagliari
#
# [718 rows x 13 columns]

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# actual_x
# 0    60
# 1    55
# Name: count, dtype: int64
